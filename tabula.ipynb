# %%
# Comment: I opted to use Tabula because the best alternative I found, Camelot, was more
# complex to use and complex to install. However, based on the amount clean-up I did,
# it would be better to use Camelot if we were processing statements from many banks.

# I expcluded tabula's depencies from requirements.text since I don't use them.
# !pip install tabula-py    

# Parse the file using Tabula.
from decimal import Decimal
import tabula
import pandas as pd

pdf_path = "statements/idfc_first_bank.pdf"

# Read the PDF as a dataframe using tabula
data_frames = tabula.read_pdf(pdf_path, pages="all")

# Remove summary table
data_frames = data_frames[1:]

# Remove first row of data_framesf[0]
data_frames[0] = data_frames[0].iloc[1:]
# Reset index of the dataframe to start at 0
data_frames[0].reset_index(drop=True, inplace=True)

# Remove column 4 from df[0]
data_frames[0].drop(data_frames[0].columns[6], axis=1, inplace=True)

# Copy columns name from data_frames[1] to data_frames[0]
data_frames[0].columns = data_frames[1].columns

# Merge all dataframes in list of dataframes into a single dataframe
df = pd.concat(data_frames)

# Re-index the data frame
df.reset_index(drop=True, inplace=True)
del data_frames

# Remove every char in particulars except spaces or alphanumerics
# like [c for c in word of c.isalnum or c == ' ']
df["Particulars"] = df["Particulars"].apply(
    lambda x: "".join(" " if c.isspace() else c for c in x)
)
# df['Particulars'] = df['Particulars'].apply(lambda x: ''.join(c for c in x if c.isalnum() or c == " "))


# Some rows were split because "Particulars" column was multiple lines
# Merge them to fix this.
for i in range(len(df) - 1):
    if pd.isna(df.loc[i + 1, "Credit"]) and pd.isna(df.loc[i + 1, "Debit"]):
        df.loc[i, "Particulars"] += df.loc[i + 1, "Particulars"]

# Remove all empty rows
df.dropna(subset=["Credit", "Debit"], how="all", inplace=True)
df.reset_index(drop=True, inplace=True)


# Replace all Debit, Credit, Balance values with decimal.Decimal. pd.NaN becomes decimal.Decimal('0.0')
df["Debit"] = df["Debit"].apply(
    lambda x: Decimal("0.0") if pd.isna(x) else Decimal(str(x).replace(",", ""))
)
df["Credit"] = df["Credit"].apply(
    lambda x: Decimal("0.0") if pd.isna(x) else Decimal(str(x).replace(",", ""))
)
df["Balance"] = df["Balance"].apply(lambda x: Decimal(str(x).replace(",", "")))
# Out:
# Error importing jpype dependencies. Fallback to subprocess.
# No module named 'jpype'
# 0 IMPS-MOB/Fund Trf/809119519742/OmaRam/BENE - VER
#
# 1 IMPS-MOB/Fund Trf/809119553510/OmaRam/2000
#
# 2 NACH/TP ACH Bajaj Finanac/88551679
#
# 3 APB-INW/HP644950 000009 3003
#
# 4 POS-VISA/KARUN MEDICAL/809414290216
#
# 5 IMPS-MOB/Fund Trf/809521437177/NITIN POOJARI/null
#
# 6 BILLPAY/RECH/VODAFONE PRE/181000095662/10042018
#
# 7 ATM-NFS/CASH WITHDRAWAL/+DONGRI OATM/810020011497
#
# 8 ATM-NFS/CASHWITHDRAWAL/+HIRANANDANI AKRUTI/810418
#
# 9 IMPS-RIB/Fund Trf/811010759849/PayRs300
#
# 10 IMPS-RIB/FT-REV/811010759849/Pay Rs300
#
# 11 POS-VISA/MANSI MEDICAL/811013502615
#
# 12 IMPS-MOB/Fund Trf/811212400262/Chandrakant Yuv/BE
#
# 13 IMPS-MOB/Fund Trf/811212428216/Chandrakant Yuv/ch
#
# 14 IMPS-RIB/Fund Trf/811212820665/Paysalary
#
# 15 IMPS-RIB/Fund Trf/811213820961/Payfor salary
#
# 16 ATM-NFS/CASHWITHDRAWAL/+HIRANANDANI AKRUTI/811309
#
# 17 IMPS-RIB/Fund Trf/811320861437/PaysalaryRs2500
#
# 18 IMPS-RIB/Fund Trf/811321862644/Pay300
#
# 19 IMPS-INET/Fund Trf/812321002185/Chandrakant Yuv/I
#
# 20 NACH/TP ACH Bajaj Finanac/97127969
#
# 21 ATM-NFS/CASH WITHDRAWAL/+WHITE HOUSE/812912009989
#
# 22 IMPS-MOB/Fund Trf/812917902484/SACH IN PANDURAN/Fr
#
# 23 IMPS-RIB/Fund Trf/813114420579/Pay salary
#
# 24 IMPS-RIB/FT-REV/813114420579/Pay sa lary
#
# 25 IMPS-RIB/Fund Trf/813117426391/Pay for arjant
#
# 26 IMPS-RIB/FT-REV/813117426391/Pay fo r arjant
#
# 27 BILLPAY/RECH/IDEA PREPAID/181320083 270/12052018
#
# 28 ATM-NFS/CASH WITHDRAWAL/+Sandhurst Road/8136190082
#
# 29 APB-INW/HP644950 012055 1405
#
# 30 IMPS-MOB/Fund Trf/813700005886/RID- 24 SP/9090
#
# 31 IMPS-MOB/Fund Trf/813800005916/RID- 24 SP/0098
#
# 32 ATM-NFS/CASHWITHDRAWAL/+WADIBUNDER /813810005906
#
# 33 ATM-NFS/CASH   WITHDRAWAL/+HIRANANDAN I AKRUTI/814016
#
# 34 POS-VISA/KARUN MEDICAL/814016444557
#
# 35 ATM-NFS/CASH   WITHDRAWAL/+HIRANANDAN I AKRUTI/814110
#
# 36 POS-VISA/FLIPKART PAYMENTS/81410945 1953
#
# 37 ATM-NFS/CASH WITHDRAWAL/+GOVANDI EA ST BR/814117029
#
# 38 POS-VISA/HOTEL SAROJ/814118881722
#
# 39 BILLPAY/RECH/VODAFONE PRE/181430064 620/23052018
#
# 40 BILLPAY/RECH/TATASKY DTH/1814300658 42/23052018
#
# 41 POS-VISA/Upper Crust Foods Pvt THAN E/815214619098
#
# 42 IMPS-MOB/FundTrf/815200006812/RID- 24 SP/Payment
#
# 43 NACH/TP ACH Bajaj Finanac/101294174
#
# 44 Charge:Cash Wdl at other ATM/Inv270 5181513668571/2
#
# 45 CGST on Charge:Cash Wdl at other AT M/Inv2705181513
#
# 46 SGST on Charge:Cash Wdl at other AT M/Inv2705181513
#
# 47 APB-INW/HP644950 018603 1106
#
# 48 CREDIT INTEREST CRED
#
# 49 IMPS-MOB/Fund Trf/818200008670/RID- 24 SP/Pay for
#
# 50 NACH/TP ACH Bajaj Finanac/108265552
#
# 51 POS-VISA/KARUN MEDICAL/818406584956
#
# 52 IMPS-MOB/Fund Trf/818600008933/RID- 24 SP/Pay forl
#
# 53 BILLPAY/QUICK/Tata Power /181862237 092/05072018
#
# 54 POS-VISA/Chembur Trombay EducatMUMB AI/818716574514
#
# 55 BILLPAY/RECH/VIDEOCON DTH/181882351 400/07072018
#
# 56 BILLPAY/RECH/AIRTEL PREPA/181882382 248/07072018
#
# 57 BILLPAY/RECH/IDEA PREPAID/181892448 103/08072018
#
# 58 POS-VISA/MANSIMEDICAL/819413057303
#
# 59 POS-VISA/MANSIMEDICAL/819413154044
#
# 60 APB-INW/HP644950 027334 1307
#
# 61 ATM-NFS/CASH   WITHDRAWAL/+HIRANANDAN I AKRUTI/820500
#
# 62 ATM-NFS/CASH   WITHDRAWAL/+HIRANANDAN I AKRUTI/820500
#
# 63 IMPS-MOB/Fund Trf/821400010710/BAYY AN MA/Ok
#
# 64 ATM-NFS/CASH WITHDRAWAL/+GRANT ROAD BR/82181001789
#
# 65 IMPS-INET/FundTrf/821922266679/Cha n/Neft_transac
#
# 66 POS-VISA/MOBIKWK/822005940645
#
# 67 ATM-NFS/CASH WITHDRAWAL/NEAR HINDUJ A COLLEGE/82251
#
# 68 POS-VISA/KARUN MEDICAL/822706734149
#
# 69 IMPS-RIB/Fund Trf/823000040666/Pay for argant
#
# 70 IMPS-MOB/Fund Trf/824301262361/FINN OVATION DIS/Ac
#
# 71 IMPS-MOB/Fund Trf/824301262609/FINN OVATION DIS/Di
#
# 72 ATM-NFS/CASH WITHDRAWAL/+BOB/824315 013476
#
# 73 POS-VISA/KARUN MEDICAL/824405792484
#
# 74 ATM-NFS/CASH WITHDRAWAL/+DEONAR ST ROAD/8244112849
#
# 75 POS-VISA/MOBIKWIK/824416007647
#
# 76 ATM-NFS/CASH WITHDRAWAL/+TATA NAGAR /824511007593
#
# 77 POS-VISA/MOBIKWIK/824604139262
#
# 78 NACH/TP ACH Bajaj Finanac/122175597
#
# 79 POS-VISA/MOBIKWIK/824711501605
#
# 80 APB-INW/HP644950 041318 2708
#
# 81 BILLPAY/RECH/VIDEOCON DTH/182486873 315/05092018
#
# 82 BILLPAY/RECHONREV/182486873315/0509 2018
#
# 83 BILLPAY/RECH/VIDEOCON DTH/182486873 393/05092018
#
# 84 ATM-NFS/CASH WITHDRAWAL/+GOLD COINA PLOT NO/825014
#
# 85 IMPS-BRC/Fund Trf/825519008950/Omar am Patel/null
#
# 86 IMPS-BRC/Fund Trf/825519011169/gopa l gopa/null
#
# 87 IMPS-BRC/FundTrf/825519012774/gopa l gopa/null
#
# 88 IMPS-BRC/FundTrf/825519012772/gopa l gopa/null
#
# 89 POS-VISA/FINNOVATION TECH SOLUTNEW DELH/8255157419
#
# 90 IMPS-MOB/Fund Trf/825611324195/FINN OVATION DIS/Di
#
# 91 IMPS-RIB/Fund Trf/825612996791/Emer gency pay
#
# 92 POS-VISA/MANSIMEDICAL/825610104558
#
# 93 IMPS-MOB/FundTrf/826100014272/RID- 24 SP/Parson
#
# 94 BILLPAY/REGBIL/Reliance Ene/1826177 27909/18092018
#
# 95 ATM-NFS/CASH   WITHDRAWAL/+HIRANANDAN I AKRUTI/826113
#
# 96 ATM-NFS/CASH WITHDRAWAL/+LAMINGTON ROAD OPERA MUMB
#
# 97 IMPS-MOB/Fund Trf/827315528457/FINN OVATION DIS/Di
#
# 98 QUATERLY SAVINGS INTEREST CREDIT
#
# 99 ATM-NFS/CASH WITHDRAWAL/SHINDE BLDG BAZAR PETHWATE
#
# 100 ATM-NFS/CASH   WITHDRAWAL/+HIRANANDAN I AKRUTI/827512
#
# 101 POS-VISA/THE BOMBAY SEEDS SUPPLMUMB AI/827509018014
#
# 102 ATM-NFS/CASH WITHDRAWAL/INDUSIND BA NK LIMITED MUMB
#
# 103 NACH/TP ACH Bajaj Finanac/129461980
#
# 104 ATM-NFS/CASH   WITHDRAWAL/+HIRANANDAN I AKRUTI/827612
#
# 105 ATM-NFS/CASH WITHDRAWAL/+NR DEONAR COLONY/82761900
#
# 106 ATM-NFS/CASH WITHDRAWAL/+LALU BHAI COMP/8277230315
#
# 107 ATM-NFS/CASH WITHDRAWAL/+LALU BHAI COMP/8278150286
#
# 108 APB-INW/HP644950 053723 0610
#
# 109 IMPS-BRC/FundTrf/828820034548/gopa l gopa/null
#
# 110 IMPS-BRC/FundTrf/828820034546/gopa l gopa/null
#
# 111 POS-VISA/FINNOVATION TECH SOLUTNEW DELH/8288155904
#
# 112 IMPS-INET/Fund Trf/828912114643/RAT NAMALA BHON/U
#
# 113 ATM-NFS/CASH WITHDRAWAL/+DOCKYARD M AZGAON/82901710
#
# 114 Charge:Cash Wdl at other ATM/Inv271 0181905826841/0
#
# 115 CGST on Charge:Cash Wdl at other AT M/Inv2710181905
#
# 116 SGST on Charge:Cash Wdl at other AT M/Inv2710181905
#
# 117 POS-VISA/SHREENATHJI CAKE/829307945 045
#
# 118 ATM-NFS/CASH WITHDRAWAL/+BSEL TECH PARKVASHI/82931
#
# 119 Charge:Cash Wdl at other ATM/Inv271 0181907118731/0
#
# 120 CGST on Charge:Cash Wdl at other AT M/Inv2710181907
#
# 121 SGST on Charge:Cash Wdl at other AT M/Inv2710181907
#
# 122 Charge:Cash Wdl at other ATM/Inv271 0181933121001/1
#
# 123 CGST on Charge:Cash Wdl at other AT M/Inv2710181933
#
# 124 SGST on Charge:Cash Wdl at other AT M/Inv2710181933
#
# 125 Charge:Cash Wdl at other ATM/Inv271 0181936795421/2
#
# 126 CGST on Charge:Cash Wdl at other AT M/Inv2710181936
#
# 127 SGST on Charge:Cash Wdl at other AT M/Inv2710181936
#
# 128 NEFT/CMS944723497/JANALAKSHMI FINA/ ICIC0000104
#
# 129 IMPS-MOB/Fund Trf/830400310349/FINN OVATION DIS/Di
#
# 130 ATM-NFS/CASH   WITHDRAWAL/+HIRANANDAN I AKRUTI/830521
#
# 131 BILLPAY/RECH/IDEA PREPAID/183050619 181/01112018
#
# 132 CHQ Paid/000001/NANGARE/KURLA NAGAR IK SAHAKARI BAN
#
# 133 ATM-NFS/CASH WITHDRAWAL/+OPERA HOUS E/830813253300
#
# 134 APB-INW/HP644950 062482 0511
#
# 135 ATM-NFS/CASH WITHDRAWAL/+UBI OPERA HOUSE/831816008
#
# 136 BILLPAY/RECH/AIRTEL PREPA/183413123 388/07122018
#
# 137 UPI/MOB/834417609963/Pest Control
#
# 138 UPI/MOB/834417611491/Pest Control P yment
#
# 139 Charge:Annual Debit Card/Inv2711181 990690691/01-NO
#
# 140 CGST on Charge:Annual Debit Card/In v27111819906906
#
# 141 SGST on Charge:Annual Debit Card/In v27111819906906
#
# 142 ATM-NFS/CASH WITHDRAWAL/+BOB/834518 004421
#
# 143 IMPS-RIB/Fund Trf/834618717058/Pay for the urgent
#
# 144 APB-INW/HP644950 073902 1212
#
# 145 IMPS-RIB/Fund Trf/834922868011/Pay for urgent
#
# 146 ATM-NFS/CASH WITHDRAWAL/+DONGRI OAT M/835118002573
#
# 147 IMPS-INET/Fund Trf/835621299970/WHI ZDMINNOVATIO/192755757354
#
# 148 IMPS-MOB/Fund Trf/835700023503/RID- 24 SP/Self
#
# 149 ATM-NFS/CASH WITHDRAWAL/+NR DEONAR COLONY/83571202
#
# 150 IMPS-MOB/Fund Trf/835718011933/FINN OVATION DIS/Disbursal KB181223RDEJE
#
# 151 BILLPAY/RECH/VODAFONE PRE/183574158 770/23122018
#
# 152 ATM-NFS/CASH WITHDRAWAL/INDUSIND BA NK LIMITED MUMB
#
# 153 ATM-NFS/CASH   WITHDRAWAL/+HIRANANDAN I AKRUTI/835917
#
# 154 IMPS-MOB/Fund Trf/836114392688/MERI TUS MEDIA P/FUND TRANSFER
#
# 155 IMPS-RIB/Fund Trf/836217435262/Pay for accounts fees
#
# 156 ATM-NFS/CASH   WITHDRAWAL/+HIRANANDAN I AKRUTI/836312
#
# 157 POS-VISA/MANSI MEDICARE/836413978489
#
# 158 QUATERLY SAVINGS INTEREST CREDIT
#
# 159 Charge:Cash Wdl at other ATM/Inv271 2181250028541/2
#
# 160 CGST on Charge:Cash Wdl at other AT M/Inv2712181250
#
# 161 SGST on Charge:Cash Wdl at other AT M/Inv2712181250
#
# 162 IMPS-BRC/Fund Trf/901020026064/Rahu l /IMPS Txn
#
# 163 IMPS-RIB/Fund Trf/901115217247/Pay for finance
#
# 164 POS-VISA/MANSI MEDICARE/901615494119
#
# 165 POS-VISA/KARUN MEDICAL/901912248047
#
# 166 POS-VISA/MANSIMEDICARE/902417531476
#
# 167 UPI/MOB/903010763900/Salary
#
# 168 POS-VISA/PHONEPE RECHARGE/903008195 064
#
# 169 APB-INW/HP644950 088903 3001
#
# 170 IMPS-RIB/Fund Trf/903302261711/Paym entforsavings
#
# 171 POS-VISA/PRAKASH LUNCH HOME/9033174 51442
#
# 172 IMPS-RIB/Fund Trf/903415349596/Paym entforsalary
#
# 173 IMPS-RIB/FT-REV/903415349596/Paymen tforsalary
#
# 174 IMPS-RIB/Fund Trf/903514406556/Paym entforsalary
#
# 175 IMPS-INET/Fund Trf/904320023197/Ami tAnilBansode/EKO
#
# 176 POS-VISA/MANSI MEDICARE/904417742636
#
# 177 ATM-NFS/CASH WITHDRAWAL/HOTEL NEETA /904501003547
#
# 178 ATM-NFS/CASH WITHDRAWAL/HOTEL NEETA /904502003548
#
# 179 UPI/MOB/904900396843/Pay for medical
#
# 180 UPI/MOB/904912046883/Payment for ma dicin
#
# 181 IMPS-MOB/Fund Trf/905800031399/RID2 4SP/Payforchandrakant
#
# 182 ATM-NFS/CASHWITHDRAWAL/+HUGHESROAD /905813031795
#
# 183 APB-INW/HP644950 098236 2702
#
# 184 UPI/MOB/906276052721/Payment made t o Merchant
#
# 185 UPI/MOB/906457345895/Payment from P honePe
#
# 186 UPI/MOB/906540003838/Payment for sa lary
#
# 187 UPI/MOB/906764615249/Rajeshbasavra j godal
#
# 188 UPI/MOB/906784098868/Payment made t o Merchant
#
# 189 UPI/MOB/906860406308/Payment from P honePe
#
# 190 UPI/MOB/906945474387/Payment made t o Merchant
#
# 191 Payment for material
#
# 192 UPI/MOB/907030799340/Payment from P honePe
#
# 193 UPI/MOB/907019957680/Verified Merch ant
#
# 194 ATM-NFS/CASH WITHDRAWAL/+NR DEONAR COLONY/90701900
#
# 195 POS-VISA/SHRIKANT LINGAM DASPELMUMB AI/907015440275
#
# 196 POS-VISA/Clues Network Private Gurg aon /9071055942
#
# 197 NEFT/FINOH19071010428/M/S EKO INDIA FINANCIAL SERVICES PR/FINO0000001
#
# 198 UPI/MOB/907211920152/Payment made t o Merchant
#
# 199 POS-VISA/COST TO COST/907212362533
#
# 200 UPI/MOB/907223556339/Verified Merch ant
#
# 201 POS-VISA/POORVIKA/907309887397
#
# 202 ATM-NFS/CASH WITHDRAWAL/+OPERA HOUS E/907414001396
#
# 203 QUARTERLY SAVINGS INTEREST CREDIT
# /Users/owenbrown/code/cascade/venv/lib/python3.11/site-packages/tabula/io.py:1045: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[c] = pd.to_numeric(df[c], errors="ignore")
# /var/folders/7r/0pxsk6n909s0q0y16qqthgp00000gn/T/ipykernel_8294/752282762.py:32: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(data_frames)

# %%
# The CEO requested the total monthly totals.
def get_total_monthly_deposits_and_credits(df: pd.DataFrame) -> int:
    df = df.copy()
    df["Transaction Date"] = pd.to_datetime(df["Transaction Date"])
    df.set_index("Transaction Date", inplace=True)
    df["End of Month"] = df.index.to_period("M").to_timestamp("M")
    df = df.groupby("End of Month")[["Debit", "Credit"]].sum()
    df["Net Change"] = df["Credit"] - df["Debit"]
    return df


# Todo: End of Month is not actually end of month, but the day of the last transaction in the month
get_total_monthly_deposits_and_credits(df)
# Out:
#                  Debit    Credit Net Change
# End of Month
# 2018-04-30    10671.00  10671.20       0.20
# 2018-05-31     9583.00   9934.06     351.06
# 2018-06-30     2196.60   2189.19      -7.41
# 2018-07-31     8554.56   8234.41    -320.15
# 2018-08-31     3540.00   7501.00    3961.00
# 2018-09-30    23234.89  26451.63    3216.74
# 2018-10-31    21062.61  68944.89   47882.28
# 2018-11-30    55479.00    408.90  -55070.10
# 2018-12-31    14317.00  14380.33      63.33
# 2019-01-31     2607.60   5610.00    3002.40
# 2019-02-28    10612.00   7567.34   -3044.66
# 2019-03-31     7859.00   7847.81     -11.19
